# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c51cc04-a3fe-4993-bc02-8790499f54a4" name="files[]" multiple disabled />
#      <output id="result-2c51cc04-a3fe-4993-bc02-8790499f54a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving UNdata_Export_20200529_080217859.csv to UNdata_Export_20200529_080217859.csv

# %%
uploaded
# Out:
# {'UNdata_Export_20200529_080217859.csv': b'"Country or Area","Year","Value"\r\n"Australia","2017","554126.561371222"\r\n"Australia","2016","546771.759766853"\r\n"Australia","2015","535173.674335188"\r\n"Australia","2014","524957.101166521"\r\n"Australia","2013","530433.518838951"\r\n"Australia","2012","540615.864771614"\r\n"Australia","2011","538280.611348808"\r\n"Australia","2010","537275.249361242"\r\n"Australia","2009","540913.370343524"\r\n"Australia","2008","537031.991694962"\r\n"Australia","2007","533138.415296519"\r\n"Australia","2006","526437.290027263"\r\n"Australia","2005","521801.010173802"\r\n"Australia","2004","515931.287064878"\r\n"Australia","2003","498118.962011473"\r\n"Australia","2002","496318.640680003"\r\n"Australia","2001","492461.68129655"\r\n"Australia","2000","485018.615860451"\r\n"Australia","1999","474027.42803065"\r\n"Australia","1998","468405.894183365"\r\n"Australia","1997","454629.299253913"\r\n"Australia","1996","442506.139039511"\r\n"Australia","1995",
# ...

# %%
print(uploaded)
# Out:
# {'UNdata_Export_20200529_080217859.csv': b'"Country or Area","Year","Value"\r\n"Australia","2017","554126.561371222"\r\n"Australia","2016","546771.759766853"\r\n"Australia","2015","535173.674335188"\r\n"Australia","2014","524957.101166521"\r\n"Australia","2013","530433.518838951"\r\n"Australia","2012","540615.864771614"\r\n"Australia","2011","538280.611348808"\r\n"Australia","2010","537275.249361242"\r\n"Australia","2009","540913.370343524"\r\n"Australia","2008","537031.991694962"\r\n"Australia","2007","533138.415296519"\r\n"Australia","2006","526437.290027263"\r\n"Australia","2005","521801.010173802"\r\n"Australia","2004","515931.287064878"\r\n"Australia","2003","498118.962011473"\r\n"Australia","2002","496318.640680003"\r\n"Australia","2001","492461.68129655"\r\n"Australia","2000","485018.615860451"\r\n"Australia","1999","474027.42803065"\r\n"Australia","1998","468405.894183365"\r\n"Australia","1997","454629.299253913"\r\n"Australia","1996","442506.139039511"\r\n"Australia","1995",
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('uploaded')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2e8df25a7878> in <module>()
# ----> 1 df=pd.read_csv('uploaded')
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['UNdata_Export_20200529_080217859.csv']))

# %%
df2.head()
# Out:
#   Country or Area  Year          Value
# 0       Australia  2017  554126.561371
# 1       Australia  2016  546771.759767
# 2       Australia  2015  535173.674335
# 3       Australia  2014  524957.101167
# 4       Australia  2013  530433.518839
